# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Yuyi Liu**
#
# Student

# %% [markdown]
# *I am interested in data science because I have worked tediously with data in the past, and didn't have the proper tools to analyze it efficiently*

# %% [markdown]
# ### Code will print "I love data science!"

# %%
print("I love data science!")
# Out:
# I love data science!

# %% [markdown]
# [Coursera Home Page](http://coursera.com/)

# %% [markdown]
# - Watson Studio
# - Github
# - Skills Network Labs

# %% [markdown]
# |car brand|model|year|
# |---------|-----|----|
# |toyota|camry|2010|
# |ford|focus|2015|
